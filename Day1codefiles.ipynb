# %%
print("welcome")
# Out:
# welcome

# %%
a=10
b=5
print(a+b)
# Out:
# 15

# %%
name=input("enter the name")
age=int(input("enter the age"))
print(name)
print(age)
# Out:
# enter the name darsani
# enter the age 18
# darsani
# 18

# %%
for i in range(1,11):
    print(i,"x","5","=",i*5)
# Out:
# 1 x 5 = 5
# 2 x 5 = 10
# 3 x 5 = 15
# 4 x 5 = 20
# 5 x 5 = 25
# 6 x 5 = 30
# 7 x 5 = 35
# 8 x 5 = 40
# 9 x 5 = 45
# 10 x 5 = 50
